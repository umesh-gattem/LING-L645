# %% [markdown]
# Tasks:
# #### 1. Data preparation
#
# - Download a translation dataset (pick a language pair) from https://www.manythings.org/anki/
#
#
#
# - Alternatively, if you prefer, download morphological segmentation data from http://turing.iimas.unam.mx/wix/static/resources/language_data.tar.bz2. You can choose which language you want to work with or even try combining them. This dataset will likely be a bit faster to train than the MT one above. Also, one trick that has been shown to work on this type of data is to add in random strings that map to themselves, in order to teach the decoder to output mostly the same characters as it sees in the input (with the addition of the morpheme boundary characters).
#
#
#
# - Create three .tsv files, one for each of train/dev/test partitions (if you use the MT data you will need to choose how to split the data, probably something like 70%/15%/15% would work). Once you have the data in this format, you smiply need to update the code in the "Load Data" section to load your data.
#
#
# - For the NMT dataset, you may need to update the tokenization function depending on your language(s).
#
#
# #### 2. Compare RNN Decoder (`Decoder` in the code) vs. RNN Decoder with Attention (`AttentionDecoder` in the code)
# - Read through the code for the Encoder, Attention, and the two Decoder classes. Make sure you have some understanding of what is going on before preceding.
#
# - Train model (for ~50-100 epochs? more if time permits...) using the "Vanilla Decoder", which is the default.
#
#
# - Make the necessary changes to the code (there should only be 2, there places are marked with a "TODO" comment) in order to run the same experiment with The AttentionDecoder.
#
#
# - Compare the results (eg the validation loss). Do you notice any difference? For now, just look at the validation loss.
#
#
# - Add to the `evaluate` function so that you also report a metric (you choose what metric). Alternatively for an easier task, complete the bleu-score function towards the end of the notebook.
#
#
# #### 3. (Bonus 1) Implement Teacher Forcing
# - Currently, in the `Seq2Seq` class's `forward()` method, there is a parameter called `teacher_forcing_ratio`, but we don't use it. "Teacher forcing" is a technique for training seq2seq models where, at each timestep, you give the decoder the correct output from the previous time step with some probability (instead of always feeding it the prediction from the previous time step, which might be wrong). Implement teacher forcing in this method. Assume `teacher_forcing_ratio` is a float between 0 and 1, and indicates the proportion of time we give the correct input to the decoder.
#
# #### 4. (Bonus 2: pobably more relevant for the morphological segmentation corpus) Compare with RNN Transducer
# - Train an RNN Transducer (from a few weeks ago) on the same data and compare the performances.

# %% [markdown]
# <hr>
#
# ### NOTES:
#
# To begin with...
#
# 1. If there is any import Error for Fields from torchtext.data, we would then need specific version of torchtext (0.8), please pip install requirements.txt which is present.
#
# To pip install from colab notebook cell-
#
# ```
# !pip install -r requirements.txt
# ```
#
#
# 2. ENG-DEU file download and train, val, test file creation-
#
# ```
# !python eng_german_sample_download.py
# ```

# %% [markdown]
# If there is OSError: ... so: undefined symbol: ... , please re-execute the cell.

# %%
# !pip3 install torchtext==0.8.0
# Out:
# Requirement already satisfied: torchtext==0.8.0 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (0.8.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from torchtext==0.8.0) (2.28.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from torchtext==0.8.0) (1.21.6)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from torchtext==0.8.0) (4.64.1)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from torchtext==0.8.0) (1.12.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests->torchtext==0.8.0) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests->torchtext==0.8.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests->torchtext==0.8.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from requests->torchtext==0.8.0) (2022.6.15)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from torch->torchtext==0.8.0) (4.3.0)
# WARNING: You are using pip version 20.1.1; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.

# %%
# !python eng_german_sample_download.py
# Out:
# python3: can't open file 'eng_german_sample_download.py': [Errno 2] No such file or directory

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchtext.data import Field, TabularDataset, BucketIterator

import numpy as np

import random
import math
import time

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/f7/4pktsxcd2mbdj2rm2c7b_28c0000gp/T/ipykernel_54506/268645904.py in <module>
#       4 import torch.nn.functional as F
#       5
# ----> 6 from torchtext.data import Field, TabularDataset, BucketIterator
#       7
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'torchtext'

# %% [markdown]
# ## Load Data
# We will use utilities from the Pytorch package "torchtext" to easily load the data and batch it using buckets according to length (in order to minimize padding)

# %%
char_tokenize = lambda s: s.split()
SRC = Field(tokenize=char_tokenize, init_token='<sow>', eos_token='<eow>', lower=True)
TGT = Field(tokenize=char_tokenize, init_token='<sow>', eos_token='<eow>', lower=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f7/4pktsxcd2mbdj2rm2c7b_28c0000gp/T/ipykernel_54506/977112786.py in <module>
#       1 char_tokenize = lambda s: s.split()
# ----> 2 SRC = Field(tokenize=char_tokenize, init_token='<sow>', eos_token='<eow>', lower=True)
#       3 TGT = Field(tokenize=char_tokenize, init_token='<sow>', eos_token='<eow>', lower=True)
#
# NameError: name 'Field' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/f7/4pktsxcd2mbdj2rm2c7b_28c0000gp/T/ipykernel_54506/1408506528.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
ls "/content/drive/MyDrive/IUB Fall 22/Advance NLP/Practicals/data/"
# Out:
# ls: /content/drive/MyDrive/IUB Fall 22/Advance NLP/Practicals/data/: No such file or directory

# %%
file_path = "/content/drive/MyDrive/IUB Fall 22/Advance NLP/Practicals/data/"

# %%
#
# TODO: Update this cell to load the dataset you chose. Once you have your data in 3 tsv 
# files (one per train/dev/test), just update the path and the names of the files.
#
path_to_data = file_path # <give your data folder location here.>

train_data, val_data, test_data = TabularDataset.splits(
        path=path_to_data, train='train.tsv', # <your train.tsv file here>
        validation='val.tsv', # <your val.tsv file here>
        test='test.tsv', # <your test.tsv file here>
        format='tsv',
        fields=[('src', SRC), ('tgt', TGT)])

# If your dataset is huge and contains many unique words, then for the sake of fast execution, you can add this argument: min_freq = <some integer>
# Only tokens that appear atleast <some integer> times then are considered. Other such words are replaced by < UNK >

SRC.build_vocab(train_data)
TGT.build_vocab(train_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchtext/data/example.py:68: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /usr/local/lib/python3.7/dist-packages/torchtext/data/example.py:78: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)

# %%
print(f"Unique tokens in source (de) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (en) vocabulary: {len(TGT.vocab)}")
# Out:
# Unique tokens in source (de) vocabulary: 323
# Unique tokens in target (en) vocabulary: 331

# %%
################################################################################################
# TODO: play with the batch size. Depending on your machine and dataset you may be able to get #
# away with much larger batches.                                                               #
################################################################################################
BATCH_SIZE = 8 

(train_iterator, valid_iterator, test_iterator) = BucketIterator.splits(
    (train_data, val_data, test_data),
    batch_size=BATCH_SIZE,
    device=device,
    sort_key=lambda x: len(x.src) # batch by length in order to minimize sequence padding
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchtext/data/iterator.py:48: UserWarning: BucketIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %% [markdown]
# ## Define Model (Encoder, Decoder, Attention Layer, and Decoder with Attention)
# We define both a "standard" decoder and an attention decoder, so that we can evaluate the impact of attention

# %% [markdown]
# ### Encoder

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout):
        super().__init__()
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim, enc_hid_dim, bidirectional = True)
        self.fc = nn.Linear(enc_hid_dim * 2, dec_hid_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):        
        embedded = self.dropout(self.embedding(src))     
        outputs, hidden = self.rnn(embedded)
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
        return outputs, hidden

# %% [markdown]
# ### Vanilla Decoder (no attention mechanism)

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, emb_dim, dec_hid_dim, dropout):
        super().__init__()
        self.output_dim = vocab_size
        self.hid_dim = dec_hid_dim
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.rnn = nn.GRU(emb_dim, dec_hid_dim)
        self.fc_out = nn.Linear(dec_hid_dim, vocab_size)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden):
        #
        # On the first time step, the hidden tensor 
        # (the context vector from the encoder) is only 2d, 
        # so we unsqueeze it.
        #
        if len(hidden.shape) == 2:
            hidden = hidden.unsqueeze(0)
            
        input = input.unsqueeze(0)        
        embedded = self.dropout(self.embedding(input))                
        outputs, hidden = self.rnn(embedded, hidden)
        prediction = self.fc_out(outputs.squeeze(0)) 
        # last value returned is for attention. Since vanilla model doesn't have attention, this value is None.       
        return prediction, hidden, None

# %% [markdown]
# ### Attention

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        self.attn = nn.Linear((enc_hid_dim * 2) + dec_hid_dim, dec_hid_dim)
        self.v = nn.Linear(dec_hid_dim, 1, bias = False)
        
    def forward(self, hidden, encoder_outputs):
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #
        # Repeat decoder hidden state src_len times in order to concatenate it 
        # with the encoder outputs.
        #
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        # energy shape: [batch size, src len, dec hid dim]
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
        # attention shape: [batch size, src len]
        attention = self.v(energy).squeeze(2)
        
        return F.softmax(attention, dim=1)

# %% [markdown]
# ### Decoder with Attention

# %%
class AttentionDecoder(nn.Module):
    def __init__(self, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout, attention):
        super().__init__()
        self.output_dim = output_dim
        self.attention = attention
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = nn.GRU((enc_hid_dim * 2) + emb_dim, dec_hid_dim)
        self.fc_out = nn.Linear((enc_hid_dim * 2) + dec_hid_dim + emb_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, encoder_outputs):
        input = input.unsqueeze(0)
        embedded = self.dropout(self.embedding(input))
        
        a = self.attention(hidden, encoder_outputs) 
        a = a.unsqueeze(1)
                
        #
        # Get weighted sum of encoder states (weighted by attention vector)
        #
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        weighted = torch.bmm(a, encoder_outputs)
        weighted = weighted.permute(1, 0, 2)
                
        rnn_input = torch.cat((embedded, weighted), dim = 2)            
        output, hidden = self.rnn(rnn_input, hidden.unsqueeze(0))
        
        #
        # Also feed the input embedding and the attended encoder representation 
        # to the fully connected output layer.
        #
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))
                
        return prediction, hidden.squeeze(0), a.squeeze(1)

# %% [markdown]
# ## Putting it all together (the Seq2Seq model)

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        batch_size = src.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        
        #encoder_outputs is all hidden states of the input sequence, back and forwards
        #hidden is the final forward and backward hidden states, passed through a linear layer
        encoder_outputs, hidden = self.encoder(src)
                
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]

        
        for t in range(1, trg_len):
            
            ################################################################## #
            # TODO*: change to accomodate the AttentionDecoder forward() call.  #
            #       You will also need to change a line in the next cell (look # 
            #       for asterisk)
            ##################################################################
            output, hidden, _ = self.decoder(input, hidden, encoder_outputs)  

            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 

            #################################################################
            # TODO: (Bonus task) implement teacher forcing here             #
            #################################################################
            input = trg[t]



        return outputs

# %% [markdown]
# ## Training Logic

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TGT.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
ENC_HID_DIM = 512
DEC_HID_DIM = 512
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

attn = Attention(ENC_HID_DIM, DEC_HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, ENC_DROPOUT)

###################################################################################################
# TODO*:                                                                                           #
# The following line defines the decoder as a Vanilla RNN (GRU) Decoder (i.e. no attention).      #
# Your task is to update this line to use the Bahdanau decoder (AttentionDecoder). You will       #
# need to check out the __init__ method of AttentionDecoder to make sure you are passing it the   #
# appropriate args.                                                                               #
###################################################################################################

# dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, DEC_HID_DIM, DEC_DROPOUT)
dec = AttentionDecoder(OUTPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, DEC_DROPOUT, attn)
# output_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout, attention


model = Seq2Seq(enc, dec, device).to(device)

def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)
            
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(323, 256)
#     (rnn): GRU(256, 512, bidirectional=True)
#     (fc): Linear(in_features=1024, out_features=512, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): AttentionDecoder(
#     (attention): Attention(
#       (attn): Linear(in_features=1536, out_features=512, bias=True)
#       (v): Linear(in_features=512, out_features=1, bias=False)
#     )
#     (embedding): Embedding(331, 256)
#     (rnn): GRU(1280, 512)
#     (fc_out): Linear(in_features=1792, out_features=331, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def train(model, iterator, optimizer, criterion, clip):
    model.train()
    epoch_loss = 0
    print("Starting training...")
    for i, batch in enumerate(iterator):
        src = batch.src
        trg = batch.tgt
        optimizer.zero_grad()
        output = model(src, trg, 0.5)  # use teacher forcing during training only.
        output_dim = output.shape[-1]
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)        
        
        loss = criterion(output, trg)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    model.eval()

    epoch_loss = 0    
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            src = batch.src
            trg = batch.tgt
            output = model(src, trg, 0) # turn off teacher forcing   
            output_dim = output.shape[-1]
            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)
            loss = criterion(output, trg)
            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 150
CLIP = 1
optimizer = optim.Adam(model.parameters(), lr=0.001)
TRG_PAD_IDX = TGT.vocab.stoi[TGT.pad_token]
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

train_losses, val_losses = [], []

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    train_losses.append(train_loss)
    val_losses.append(valid_loss)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut3-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f}')
# Out:
# Starting training...
# /usr/local/lib/python3.7/dist-packages/torchtext/data/batch.py:23: UserWarning: Batch class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# Epoch: 01 | Time: 0m 0s
# 	Train Loss: 5.858
# 	 Val. Loss: 5.483
# Starting training...
# Epoch: 02 | Time: 0m 0s
# 	Train Loss: 5.147
# 	 Val. Loss: 5.700
# Starting training...
# Epoch: 03 | Time: 0m 0s
# 	Train Loss: 4.850
# 	 Val. Loss: 6.081
# Starting training...
# Epoch: 04 | Time: 0m 0s
# 	Train Loss: 4.576
# 	 Val. Loss: 6.224
# Starting training...
# Epoch: 05 | Time: 0m 0s
# 	Train Loss: 4.391
# 	 Val. Loss: 6.255
# Starting training...
# Epoch: 06 | Time: 0m 0s
# 	Train Loss: 4.230
# 	 Val. Loss: 6.586
# Starting training...
# Epoch: 07 | Time: 0m 0s
# 	Train Loss: 4.067
# 	 Val. Loss: 7.122
# Starting training...
# Epoch: 08 | Time: 0m 0s
# 	Train Loss: 3.910
# 	 Val. Loss: 7.419
# Starting training...
# Epoch: 09 | Time: 0m 0s
# 	Train Loss: 3.776
# 	 Val. Loss: 7.522
# Starting training...
# Epoch: 10 | Time: 0m 0s
# 	Train Loss: 3.635
# 	 Val. Loss: 7.602
# Starting training...
# Epoch: 11 | Time: 0m 0s
# 	Train Loss: 3.379
# 	 Val. Loss: 7.691
# Starting training...
# Epoch: 12 | Time: 0m 0s
# 	Train Loss: 3.257
# 	 Val. Loss: 7.895
# Starting training...
# Epoch: 13 | Time: 0m 0s
# 	Train Loss: 3.070
# 	 Val. Loss: 8.301
# Starting training...
# Epoch: 14 | Time: 0m 0s
# 	Train Loss: 2.793
# 	 Val. Loss: 8.454
# Starting training...
# Epoch: 15 | Time: 0m 0s
# 	Train Loss: 2.666
# 	 Val. Loss: 8.321
# Starting training...
# Epoch: 16 | Time: 0m 0s
# 	Train Loss: 2.421
# 	 Val. Loss: 8.574
# Starting training...
# Epoch: 17 | Time: 0m 0s
# 	Train Loss: 2.269
# 	 Val. Loss: 8.552
# Starting training...
# Epoch: 18 | Time: 0m 0s
# 	Train Loss: 2.036
# 	 Val. Loss: 8.862
# Starting training...
# Epoch: 19 | Time: 0m 0s
# 	Train Loss: 1.810
# 	 Val. Loss: 9.298
# Starting training...
# Epoch: 20 | Time: 0m 0s
# 	Train Loss: 1.622
# 	 Val. Loss: 9.318
# Starting training...
# Epoch: 21 | Time: 0m 0s
# 	Train Loss: 1.473
# 	 Val. Loss: 9.679
# Starting training...
# Epoch: 22 | Time: 0m 0s
# 	Train Loss: 1.302
# 	 Val. Loss: 9.415
# Starting training...
# Epoch: 23 | Time: 0m 0s
# 	Train Loss: 1.184
# 	 Val. Loss: 9.965
# Starting training...
# Epoch: 24 | Time: 0m 0s
# 	Train Loss: 1.020
# 	 Val. Loss: 10.257
# Starting training...
# Epoch: 25 | Time: 0m 0s
# 	Train Loss: 0.914
# 	 Val. Loss: 10.437
# Starting training...
# Epoch: 26 | Time: 0m 0s
# 	Train Loss: 0.783
# 	 Val. Loss: 10.641
# Starting training...
# Epoch: 27 | Time: 0m 0s
# 	Train Loss: 0.654
# 	 Val. Loss: 10.630
# Starting training...
# Epoch: 28 | Time: 0m 0s
# 	Train Loss: 0.531
# 	 Val. Loss: 10.949
# Starting training...
# Epoch: 29 | Time: 0m 0s
# 	Train Loss: 0.491
# 	 Val. Loss: 11.300
# Starting training...
# Epoch: 30 | Time: 0m 0s
# 	Train Loss: 0.503
# 	 Val. Loss: 11.069
# Starting training...
# Epoch: 31 | Time: 0m 0s
# 	Train Loss: 0.403
# 	 Val. Loss: 11.099
# Starting training...
# Epoch: 32 | Time: 0m 0s
# 	Train Loss: 0.352
# 	 Val. Loss: 11.513
# Starting training...
# Epoch: 33 | Time: 0m 0s
# 	Train Loss: 0.292
# 	 Val. Loss: 11.549
# Starting training...
# Epoch: 34 | Time: 0m 0s
# 	Train Loss: 0.303
# 	 Val. Loss: 11.331
# Starting training...
# Epoch: 35 | Time: 0m 0s
# 	Train Loss: 0.235
# 	 Val. Loss: 11.845
# Starting training...
# Epoch: 36 | Time: 0m 0s
# 	Train Loss: 0.192
# 	 Val. Loss: 11.847
# Starting training...
# Epoch: 37 | Time: 0m 0s
# 	Train Loss: 0.146
# 	 Val. Loss: 11.951
# Starting training...
# Epoch: 38 | Time: 0m 0s
# 	Train Loss: 0.165
# 	 Val. Loss: 12.068
# Starting training...
# Epoch: 39 | Time: 0m 0s
# 	Train Loss: 0.163
# 	 Val. Loss: 12.027
# Starting training...
# Epoch: 40 | Time: 0m 0s
# 	Train Loss: 0.121
# 	 Val. Loss: 12.087
# Starting training...
# Epoch: 41 | Time: 0m 0s
# 	Train Loss: 0.114
# 	 Val. Loss: 12.154
# Starting training...
# Epoch: 42 | Time: 0m 0s
# 	Train Loss: 0.070
# 	 Val. Loss: 12.311
# Starting training...
# Epoch: 43 | Time: 0m 0s
# 	Train Loss: 0.070
# 	 Val. Loss: 12.268
# Starting training...
# Epoch: 44 | Time: 0m 0s
# 	Train Loss: 0.063
# 	 Val. Loss: 12.462
# Starting training...
# Epoch: 45 | Time: 0m 0s
# 	Train Loss: 0.065
# 	 Val. Loss: 12.702
# Starting training...
# Epoch: 46 | Time: 0m 0s
# 	Train Loss: 0.035
# 	 Val. Loss: 12.686
# Starting training...
# Epoch: 47 | Time: 0m 0s
# 	Train Loss: 0.037
# 	 Val. Loss: 12.741
# Starting training...
# Epoch: 48 | Time: 0m 0s
# 	Train Loss: 0.025
# 	 Val. Loss: 12.781
# Starting training...
# Epoch: 49 | Time: 0m 0s
# 	Train Loss: 0.021
# 	 Val. Loss: 12.964
# Starting training...
# Epoch: 50 | Time: 0m 0s
# 	Train Loss: 0.017
# 	 Val. Loss: 12.947
# Starting training...
# Epoch: 51 | Time: 0m 0s
# 	Train Loss: 0.021
# 	 Val. Loss: 12.973
# Starting training...
# Epoch: 52 | Time: 0m 0s
# 	Train Loss: 0.015
# 	 Val. Loss: 12.863
# Starting training...
# Epoch: 53 | Time: 0m 0s
# 	Train Loss: 0.017
# 	 Val. Loss: 13.215
# Starting training...
# Epoch: 54 | Time: 0m 0s
# 	Train Loss: 0.033
# 	 Val. Loss: 12.952
# Starting training...
# Epoch: 55 | Time: 0m 0s
# 	Train Loss: 0.015
# 	 Val. Loss: 13.213
# Starting training...
# Epoch: 56 | Time: 0m 0s
# 	Train Loss: 0.014
# 	 Val. Loss: 13.123
# Starting training...
# Epoch: 57 | Time: 0m 0s
# 	Train Loss: 0.017
# 	 Val. Loss: 13.159
# Starting training...
# Epoch: 58 | Time: 0m 0s
# 	Train Loss: 0.019
# 	 Val. Loss: 13.155
# Starting training...
# Epoch: 59 | Time: 0m 0s
# 	Train Loss: 0.025
# 	 Val. Loss: 13.108
# Starting training...
# Epoch: 60 | Time: 0m 0s
# 	Train Loss: 0.018
# 	 Val. Loss: 12.994
# Starting training...
# Epoch: 61 | Time: 0m 0s
# 	Train Loss: 0.011
# 	 Val. Loss: 12.995
# Starting training...
# Epoch: 62 | Time: 0m 0s
# 	Train Loss: 0.015
# 	 Val. Loss: 13.046
# Starting training...
# Epoch: 63 | Time: 0m 0s
# 	Train Loss: 0.028
# 	 Val. Loss: 13.019
# Starting training...
# Epoch: 64 | Time: 0m 0s
# 	Train Loss: 0.030
# 	 Val. Loss: 13.112
# Starting training...
# Epoch: 65 | Time: 0m 0s
# 	Train Loss: 0.009
# 	 Val. Loss: 13.168
# Starting training...
# Epoch: 66 | Time: 0m 0s
# 	Train Loss: 0.006
# 	 Val. Loss: 13.277
# Starting training...
# Epoch: 67 | Time: 0m 0s
# 	Train Loss: 0.007
# 	 Val. Loss: 13.303
# Starting training...
# Epoch: 68 | Time: 0m 0s
# 	Train Loss: 0.005
# 	 Val. Loss: 13.313
# Starting training...
# Epoch: 69 | Time: 0m 0s
# 	Train Loss: 0.004
# 	 Val. Loss: 13.358
# Starting training...
# Epoch: 70 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.399
# Starting training...
# Epoch: 71 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.438
# Starting training...
# Epoch: 72 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.459
# Starting training...
# Epoch: 73 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.485
# Starting training...
# Epoch: 74 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.505
# Starting training...
# Epoch: 75 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.566
# Starting training...
# Epoch: 76 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.584
# Starting training...
# Epoch: 77 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.623
# Starting training...
# Epoch: 78 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.628
# Starting training...
# Epoch: 79 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.652
# Starting training...
# Epoch: 80 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.635
# Starting training...
# Epoch: 81 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.689
# Starting training...
# Epoch: 82 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.731
# Starting training...
# Epoch: 83 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.762
# Starting training...
# Epoch: 84 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.765
# Starting training...
# Epoch: 85 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.757
# Starting training...
# Epoch: 86 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.771
# Starting training...
# Epoch: 87 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.785
# Starting training...
# Epoch: 88 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.816
# Starting training...
# Epoch: 89 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.820
# Starting training...
# Epoch: 90 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.819
# Starting training...
# Epoch: 91 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.832
# Starting training...
# Epoch: 92 | Time: 0m 0s
# 	Train Loss: 0.006
# 	 Val. Loss: 13.901
# Starting training...
# Epoch: 93 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.948
# Starting training...
# Epoch: 94 | Time: 0m 0s
# 	Train Loss: 0.007
# 	 Val. Loss: 13.960
# Starting training...
# Epoch: 95 | Time: 0m 0s
# 	Train Loss: 0.013
# 	 Val. Loss: 13.875
# Starting training...
# Epoch: 96 | Time: 0m 0s
# 	Train Loss: 0.007
# 	 Val. Loss: 13.981
# Starting training...
# Epoch: 97 | Time: 0m 0s
# 	Train Loss: 0.013
# 	 Val. Loss: 13.894
# Starting training...
# Epoch: 98 | Time: 0m 0s
# 	Train Loss: 0.025
# 	 Val. Loss: 13.766
# Starting training...
# Epoch: 99 | Time: 0m 0s
# 	Train Loss: 0.043
# 	 Val. Loss: 13.326
# Starting training...
# Epoch: 100 | Time: 0m 0s
# 	Train Loss: 0.031
# 	 Val. Loss: 13.886
# Starting training...
# Epoch: 101 | Time: 0m 0s
# 	Train Loss: 0.039
# 	 Val. Loss: 13.951
# Starting training...
# Epoch: 102 | Time: 0m 0s
# 	Train Loss: 0.126
# 	 Val. Loss: 13.752
# Starting training...
# Epoch: 103 | Time: 0m 0s
# 	Train Loss: 0.104
# 	 Val. Loss: 13.818
# Starting training...
# Epoch: 104 | Time: 0m 0s
# 	Train Loss: 0.070
# 	 Val. Loss: 13.065
# Starting training...
# Epoch: 105 | Time: 0m 0s
# 	Train Loss: 0.118
# 	 Val. Loss: 13.717
# Starting training...
# Epoch: 106 | Time: 0m 0s
# 	Train Loss: 0.091
# 	 Val. Loss: 13.132
# Starting training...
# Epoch: 107 | Time: 0m 0s
# 	Train Loss: 0.078
# 	 Val. Loss: 13.384
# Starting training...
# Epoch: 108 | Time: 0m 0s
# 	Train Loss: 0.056
# 	 Val. Loss: 13.028
# Starting training...
# Epoch: 109 | Time: 0m 0s
# 	Train Loss: 0.051
# 	 Val. Loss: 13.045
# Starting training...
# Epoch: 110 | Time: 0m 0s
# 	Train Loss: 0.035
# 	 Val. Loss: 13.501
# Starting training...
# Epoch: 111 | Time: 0m 0s
# 	Train Loss: 0.043
# 	 Val. Loss: 13.027
# Starting training...
# Epoch: 112 | Time: 0m 0s
# 	Train Loss: 0.020
# 	 Val. Loss: 13.162
# Starting training...
# Epoch: 113 | Time: 0m 0s
# 	Train Loss: 0.036
# 	 Val. Loss: 13.475
# Starting training...
# Epoch: 114 | Time: 0m 0s
# 	Train Loss: 0.028
# 	 Val. Loss: 13.720
# Starting training...
# Epoch: 115 | Time: 0m 0s
# 	Train Loss: 0.053
# 	 Val. Loss: 13.513
# Starting training...
# Epoch: 116 | Time: 0m 0s
# 	Train Loss: 0.043
# 	 Val. Loss: 13.435
# Starting training...
# Epoch: 117 | Time: 0m 0s
# 	Train Loss: 0.015
# 	 Val. Loss: 13.533
# Starting training...
# Epoch: 118 | Time: 0m 0s
# 	Train Loss: 0.018
# 	 Val. Loss: 13.492
# Starting training...
# Epoch: 119 | Time: 0m 0s
# 	Train Loss: 0.008
# 	 Val. Loss: 13.461
# Starting training...
# Epoch: 120 | Time: 0m 0s
# 	Train Loss: 0.018
# 	 Val. Loss: 13.557
# Starting training...
# Epoch: 121 | Time: 0m 0s
# 	Train Loss: 0.042
# 	 Val. Loss: 13.449
# Starting training...
# Epoch: 122 | Time: 0m 0s
# 	Train Loss: 0.032
# 	 Val. Loss: 13.387
# Starting training...
# Epoch: 123 | Time: 0m 0s
# 	Train Loss: 0.018
# 	 Val. Loss: 13.367
# Starting training...
# Epoch: 124 | Time: 0m 0s
# 	Train Loss: 0.017
# 	 Val. Loss: 13.423
# Starting training...
# Epoch: 125 | Time: 0m 0s
# 	Train Loss: 0.024
# 	 Val. Loss: 13.483
# Starting training...
# Epoch: 126 | Time: 0m 0s
# 	Train Loss: 0.009
# 	 Val. Loss: 13.582
# Starting training...
# Epoch: 127 | Time: 0m 0s
# 	Train Loss: 0.013
# 	 Val. Loss: 13.589
# Starting training...
# Epoch: 128 | Time: 0m 0s
# 	Train Loss: 0.020
# 	 Val. Loss: 13.444
# Starting training...
# Epoch: 129 | Time: 0m 0s
# 	Train Loss: 0.016
# 	 Val. Loss: 13.394
# Starting training...
# Epoch: 130 | Time: 0m 0s
# 	Train Loss: 0.018
# 	 Val. Loss: 13.695
# Starting training...
# Epoch: 131 | Time: 0m 0s
# 	Train Loss: 0.035
# 	 Val. Loss: 13.682
# Starting training...
# Epoch: 132 | Time: 0m 0s
# 	Train Loss: 0.012
# 	 Val. Loss: 13.579
# Starting training...
# Epoch: 133 | Time: 0m 0s
# 	Train Loss: 0.003
# 	 Val. Loss: 13.623
# Starting training...
# Epoch: 134 | Time: 0m 0s
# 	Train Loss: 0.002
# 	 Val. Loss: 13.642
# Starting training...
# Epoch: 135 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.622
# Starting training...
# Epoch: 136 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.638
# Starting training...
# Epoch: 137 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.677
# Starting training...
# Epoch: 138 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.709
# Starting training...
# Epoch: 139 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.731
# Starting training...
# Epoch: 140 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.739
# Starting training...
# Epoch: 141 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.738
# Starting training...
# Epoch: 142 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.740
# Starting training...
# Epoch: 143 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.750
# Starting training...
# Epoch: 144 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.766
# Starting training...
# Epoch: 145 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.781
# Starting training...
# Epoch: 146 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.793
# Starting training...
# Epoch: 147 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.808
# Starting training...
# Epoch: 148 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.828
# Starting training...
# Epoch: 149 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.845
# Starting training...
# Epoch: 150 | Time: 0m 0s
# 	Train Loss: 0.001
# 	 Val. Loss: 13.860

# %% [markdown]
# ## Inference
#
# The following blocks are only valid for attention model. If you are executing Vanilla Decoder, then stop here!

# %% [markdown]
# We are now going to machine translate some sentences using our trained attention model.
#
# The function takes in sentence to translate, SRC, TGT fields and the model and returns predicted sentence and attention values over the sequence.

# %%
def translate_sentence(sentence, src_field, trg_field, model, device, max_len=50):
    model.eval()

    tokens = [token.lower() for token in sentence]
    # Add start of sentence and end of sentence to the tokens
    tokens = [src_field.init_token] + tokens + [src_field.eos_token]

    # Numericalize the source sentence
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]
    # src_indexes shape = [src_len]

    # Convert to tensor and add batch dimension.
    src_tensor = torch.LongTensor(src_indexes).unsqueeze(1).to(device)

    # Feed source sentence into encoder
    with torch.no_grad():
        encoder_outputs, hidden = model.encoder(src_tensor)
    
    # create a list to hold the output sentence, initialized with an <sos> token
    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]

    # create a tensor to hold the attention values
    attentions = torch.zeros(max_len, 1, len(src_indexes)).to(device)

    for i in range(max_len):
        trg_tensor = torch.LongTensor([trg_indexes[-1]]).to(device)
        with torch.no_grad():
            output, hidden, attention = model.decoder(trg_tensor, hidden, encoder_outputs)
        attentions[i] = attention
        pred_token = output.argmax(1).item()
        trg_indexes.append(pred_token)

        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
    
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]

    return trg_tokens[1:], attentions[:len(trg_tokens)-1]

# %% [markdown]
# Function to display attention visualization

# %%
def display_attention(sentence, translation, attention):
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    
    attention = attention.squeeze(1).cpu().detach().numpy()
    
    cax = ax.matshow(attention, cmap='bone')
   
    ax.tick_params(labelsize=15)
    ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                       rotation=45)
    ax.set_yticklabels(['']+translation)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()

# %% [markdown]
# ### Inference on some test sentences

# %%
example_idx = 20

src = vars(train_data.examples[example_idx])['src']
trg = vars(train_data.examples[example_idx])['tgt']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['you', 'must', 'stay', 'where', 'you', 'are.']
# trg = ['నువ్వు', 'ఎక్కడ', 'ఉన్నవో', 'అక్కడే', 'ఉండు']

# %%
translation, attention = translate_sentence(src, SRC, TGT, model, device)

print(f'predicted trg = {translation}')
# Out:
# predicted trg = ['నువ్వు', 'ఎక్కడ', 'ఉన్నవో', 'అక్కడే', 'ఉండు', '<eow>']

# %%
display_attention(src, translation, attention)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3125 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3086 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3081 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 3125 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 3086 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 3081 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 3147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 3077 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### Bleu score calculation on test set

# %%
from torchtext.data.metrics import bleu_score

def calculate_bleu(data, src_field, trg_field, model, device, max_len = 50):
    
    trgs = []
    pred_trgs = []
    
    for datum in data:
        
        src = vars(datum)['src']
        tgt = vars(datum)['tgt']
        
        pred_trg, _ = translate_sentence(src, src_field, trg_field, model, device, max_len)
        
        #cut off <eos> token
        pred_trg = pred_trg[:-1]
        
        pred_trgs.append(pred_trg)
        trgs.append([tgt])
    return bleu_score(pred_trgs, trgs)
        ################################################################
        # TODO: call the bleu score function here and return the result#
        ################################################################

# %%
bleu_score = calculate_bleu(test_data, SRC, TGT, model, device)

print(f'BLEU score = {bleu_score*100:.2f}')
# Out:
# BLEU score = 0.00
